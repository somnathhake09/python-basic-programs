# %%
#sum all list
list=[25,63,54,25]
print((list))
# Out:
# 25 63 54 25

# %%
#multipli all list
numbers=[12,34,54,56,23]
result=1
for num in numbers:
    result*=num
print("multiplaction the numbers:",result)
# Out:
# multiplaction the numbers: 28377216

# %%
#tuple from a given list of non-empty tuples
s=tuple(input("enter the value of tuple"))
if not s:
    print("this tuple is empty")
else:
    print("this tuple is no-empty")
# Out:
# enter the value of tuple 123
# this tuple is no-empty

# %%
#tuple cerate
tuple=(1,2,3,4,5,65,6)
print(tuple)
# Out:
# (1, 2, 3, 4, 5, 65, 6)

# %%
#tuple different data type
s=(9,"soma",False,23.14)
for v in s:
    print("tuple:",tuple)
    print(type(v))
# Out:
# tuple: (9, 'soma', False, 23.14)
# <class 'int'>
# tuple: (9, 'soma', False, 23.14)
# <class 'str'>
# tuple: (9, 'soma', False, 23.14)
# <class 'bool'>
# tuple: (9, 'soma', False, 23.14)
# <class 'float'>

# %%
#wether check an exist within a tuple
s=(546,52,45,9)
h=int(input("enter the element:"))
if h in s:
    print("this is num exist")
else:
    print("this is num not exist")
# Out:
# enter the element: 546
# this is num exist

# %%
#crate a set
s={25,63,96,55,6,5,56,1361,6,652,25}
print(s)
# Out:
# {96, 5, 6, 652, 1361, 55, 56, 25, 63}

# %%
#iterate over set
s={9,8,7,6,5,4,3,2,1}
for sh in s:
    print(sh)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#create set difference
s={1,2,3,5,6,5,69,2,2,21,56,58,56}
h={9,8,7,4,5,6,1,2,3,99}
d=s.difference(h)
print(d)
# Out:
# {56, 21, 58, 69}

# %%
# decending & ascending dictionary by value
s ={8,9,56,5,6,54}
h ={8,5,6,4,63,}
s =list(s)
h =list(h)
s.sort()
h.sort(reverse=True)
print(s)
print(h)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       2 s ={8,9,56,5,6,54,5,5,6,4,6,47,6}
#       3 h ={8,5,6,4,63,52,96,6,12,4,6,85,3,6,56}
# ----> 4 s =list(s)
#       5 h =list(h)
#       6 s.sort()
#
# TypeError: 'set' object is not callable

# %%
#add a key dictionary
s ={'name':"somnath",'dream':"bilinore"}
s['car']="bmw"
print(s)
# Out:
# {'name': 'somnath', 'dream': 'bilinore', 'car': 'bmw'}

# %%
#iterate over dictionaries using loop
s={23,45,645,67}
for h in s:
    print(h)
# Out:
# 67
# 45
# 645
# 23

# %%
#set B
s=["chtrapti","shivaji", "maharaj"]
print(s)
del s[1]
print("the remove duplicates")
